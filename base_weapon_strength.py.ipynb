# %% [markdown]
# # Analyze Base Kit Strength
#
# First, we will analyze just kit strength.
# We will create a model that predicts battle results based
# only on the sum of the kit strengths of the two teams.
# Besides ignoring player skills, this model will also ignore
# synergies between kits on the same team, anti-synergies
# between kits on opposite teams, game versions, maps,
# and game modes.

# %%
import logging

logger = logging.getLogger("analyze_base_kit_strength_notebook")
logging.basicConfig(level=logging.INFO)

# %% [markdown]
# ## Demo battle record creator
# Here is a small battle record creator for refining the model

# %%
from battle_record import BattleRecord
from typing import Generator


def some_battle_records() -> Generator[BattleRecord, None, None]:
    from read_battle_records import battle_records_from_zip

    return battle_records_from_zip("2024-04-26.zip")

# %%
def mar_apr_battle_records() -> Generator[BattleRecord, None, None]:
    """Records for March 27 - April 26, 2024 inclusive"""
    from read_battle_records import battle_records_from_zip

    return battle_records_from_zip("2024-mar-apr-battles.zip")

# %% [markdown]
# ## Duplicate kit_only_model code
#
# For the sake of not having to reload the libraries constantly, we will duplicate the code
# from the `kit_only_model` function in the `battle_record_analysis` module. This will enable
# faster iteration.

# %%
import pytensor.tensor as tt
from battle_record_analysis import (
    all_kits_used,
    all_observed_kit_variables_and_battle_results,
)
import pymc as pm
from typing import Callable, Iterable


def kit_only_model(
    battle_record_creator: Callable[[], Iterable[BattleRecord]]
) -> pm.Model:
    """
    Create a PyMC3 model for the given battle record creator.

    Here is the formula for each battle record:
    kit_strength = pm.Exp("kit_strength", 1, dims=("kits",))
    both_sides_kit_strengths = concatenate(kit_strength, kit_strength)
    num_and_den_kit_strengths = concatenate(both_sides_kit_strengths, both_sides_kit_strengths)
    num_and_den_observed_kits = concatenate(observed_kit_variables, -abs(observed_kit_variables))
    The basic formula is prob_team_alpha_win for each battle = exp(
        dot(num_and_den_kit_strengths, num_and_den_observed_kits)
    )
    Kit strength's prior distributed as an exponential variable with mean 1

    Args:
        battle_record_creator: A callable that returns an
            iterable of battle records (generally by re-opening the file)

    Returns:
        A PyMC3 model for the given battle record creator.
    """
    kits = sorted(all_kits_used(battle_record_creator()))
    kit_index = {kit: i for i, kit in enumerate(kits)}
    observed_kit_variables, battle_results = (
        all_observed_kit_variables_and_battle_results(
            battle_record_creator(), kit_index
        )
    )
    logger.info(f"Done reading.")
    logger.info(f"Number of kits: {len(kits)}")
    logger.info(f"Shape of observed_kit_variables: {observed_kit_variables.shape}")
    logger.info(f"Shape of battle_results: {battle_results.shape}")

    coords = {"kits": kits}
    with pm.Model(coords=coords) as model:
        observed_kit_data = pm.Data("observed_kit_data", observed_kit_variables)
        battle_results_data = pm.Data("battle_results_data", battle_results)

        kit_strength = tt.reshape(
            pm.Exponential("kit_strength", 1, dims="kits"), (1, -1)
        )
        both_sides_kit_strengths = pm.math.concatenate(
            [kit_strength, kit_strength], axis=1
        )
        single_row_num_and_den_kit_strengths = pm.math.concatenate(
            [both_sides_kit_strengths, both_sides_kit_strengths], axis=1
        )
        logger.info(
            f"Shape of single_row_num_and_den_kit_strengths: {single_row_num_and_den_kit_strengths.shape.eval()}"
        )
        num_and_den_kit_strengths = tt.repeat(
            single_row_num_and_den_kit_strengths,
            observed_kit_data.shape[0],
            axis=0,
        )
        logger.info(
            f"Shape of num_and_den_kit_strengths: {num_and_den_kit_strengths.shape.eval()}"
        )

        num_and_den_observed_kits = pm.math.concatenate(
            [observed_kit_data, -abs(observed_kit_data)], axis=1
        )
        logger.info(
            f"Shape of num_and_den_observed_kits: {num_and_den_observed_kits.shape.eval()}"
        )

        kit_contributions = num_and_den_kit_strengths * num_and_den_observed_kits
        team_alpha_strength = tt.reshape(tt.sum(kit_contributions, axis=1), (-1, 1))
        logger.info(f"Shape of team_alpha_strength: {team_alpha_strength.shape.eval()}")

        prob_team_alpha_win = pm.math.exp(team_alpha_strength)
        pm.Bernoulli(
            "battle_results", prob_team_alpha_win, observed=battle_results_data
        )

    return model
# Out:
# INFO:numexpr.utils:Note: NumExpr detected 16 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# INFO:numexpr.utils:NumExpr defaulting to 8 threads.

# %%
# Vanilla sampler took 18:06 for 1000 samples and 1000 tune
# Nutpie sampler took 16:24 for 1000 samples and 1000 tune
with kit_only_model(some_battle_records) as small_model:
    kit_only_trace = pm.sample(
        1000, tune=1000, cores=4, progressbar=True, nuts_sampler="nutpie"
    )
# Out:
# Tallying weapons used: 0it [00:00, ?it/s]
# Reading battles:   0%|          | 0.00/9.98M [00:00<?, ?Bytes/s]
# Tallying weapons used: 5872it [00:00, 12304.34it/s]<?, ?Bytes/s, 2024-04-26.csv]
# Reading battles: 100%|██████████| 9.98M/9.98M [00:00<00:00, 20.5MBytes/s, 2024-04-26.csv]
# Tallying weapons used: 6095it [00:00, 11668.14it/s]
# Processing battle records: 0it [00:00, ?it/s]
# Reading battles:   0%|          | 0.00/9.98M [00:00<?, ?Bytes/s]
# Processing battle records: 5492it [00:00, 11059.87it/s]?Bytes/s, 2024-04-26.csv]
# Reading battles: 100%|██████████| 9.98M/9.98M [00:00<00:00, 18.0MBytes/s, 2024-04-26.csv]
# Processing battle records: 6095it [00:00, 10919.83it/s]
# INFO:analyze_base_weapon_strength_notebook:Done reading.
# INFO:analyze_base_weapon_strength_notebook:Number of weapons: 120
# INFO:analyze_base_weapon_strength_notebook:Shape of observed_weapon_variables: (6095, 240)
# INFO:analyze_base_weapon_strength_notebook:Shape of battle_results: (6095, 1)
# INFO:analyze_base_weapon_strength_notebook:Shape of single_row_num_and_den_weapon_strengths: [  1 480]
# INFO:analyze_base_weapon_strength_notebook:Shape of num_and_den_weapon_strengths: [6095  480]
# INFO:analyze_base_weapon_strength_notebook:Shape of num_and_den_observed_weapons: [6095  480]
# INFO:analyze_base_weapon_strength_notebook:Shape of team_alpha_strength: [6095    1]
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='8000' class='' max='8000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [8000/8000 16:24&lt;00:00  Sampling chains: 0, Divergences: 0]
#     </div>

# %%
import pickle

pickle.dump(kit_only_trace, open("2024-04-26.kit_only_trace.pkl", "wb"))

# %%
import arviz as az

az.summary(kit_only_trace)
# Out:
#                                mean     sd  hdi_3%  hdi_97%  mcse_mean  \
# weapon_strength[52gal]        0.101  0.014   0.074    0.127      0.000
# weapon_strength[52gal_deco]   0.124  0.028   0.072    0.179      0.000
# weapon_strength[96gal]        0.041  0.036   0.000    0.106      0.000
# weapon_strength[96gal_deco]   0.070  0.033   0.008    0.128      0.001
# weapon_strength[bamboo14mk1]  0.050  0.039   0.000    0.120      0.001
# ...                             ...    ...     ...      ...        ...
# weapon_strength_log__[115]   -2.845  0.509  -3.794   -2.071      0.009
# weapon_strength_log__[116]   -2.715  0.760  -3.962   -1.586      0.020
# weapon_strength_log__[117]   -2.596  0.240  -3.052   -2.169      0.003
# weapon_strength_log__[118]   -3.035  1.147  -5.108   -1.338      0.027
# weapon_strength_log__[119]   -2.199  0.748  -3.564   -1.113      0.017
#
#                               mcse_sd  ess_bulk  ess_tail  r_hat
# weapon_strength[52gal]          0.000    7729.0    2670.0   1.00
# weapon_strength[52gal_deco]     0.000    7719.0    2206.0   1.00
# weapon_strength[96gal]          0.000    3598.0    1575.0   1.00
# weapon_strength[96gal_deco]     0.000    3022.0    1283.0   1.01
# weapon_strength[bamboo14mk1]    0.000    3932.0    2206.0   1.00
# ...                               ...       ...       ...    ...
# weapon_strength_log__[115]      0.007    4837.0    2087.0   1.00
# weapon_strength_log__[116]      0.016    3054.0    1527.0   1.00
# weapon_strength_log__[117]      0.002    7299.0    2523.0   1.00
# weapon_strength_log__[118]      0.022    3179.0    1733.0   1.00
# weapon_strength_log__[119]      0.015    3763.0    1556.0   1.00
#
# [240 rows x 9 columns]

# %%
az.plot_trace(kit_only_trace)
# Out:
# array([[<Axes: title={'center': 'weapon_strength'}>,
#         <Axes: title={'center': 'weapon_strength'}>],
#        [<Axes: title={'center': 'weapon_strength_log__'}>,
#         <Axes: title={'center': 'weapon_strength_log__'}>]], dtype=object)

# %%
with kit_only_model(mar_apr_battle_records) as mar_apr_model:
    mar_apr_kit_only_trace = pm.sample(
        1000, tune=1000, cores=4, progressbar=True, nuts_sampler="nutpie"
    )
# Out:
# Tallying weapons used: 0it [00:00, ?it/s]
# Reading battles:   0%|          | 0.00/323M [00:00<?, ?Bytes/s]
# Tallying weapons used: 5095it [00:00, 12786.70it/s]?, ?Bytes/s, 2024-03-27.csv]
# Reading battles:   3%|▎         | 8.48M/323M [00:00<00:15, 20.9MBytes/s, 2024-03-27.csv]
# Tallying weapons used: 8957it [00:00, 12832.10it/s]<00:15, 20.9MBytes/s, 2024-03-28.csv]
# Reading battles:   5%|▌         | 16.4M/323M [00:00<00:14, 21.0MBytes/s, 2024-03-28.csv]
# Tallying weapons used: 15437it [00:01, 12896.14it/s]00:14, 21.0MBytes/s, 2024-03-29.csv]
# Reading battles:   8%|▊         | 26.3M/323M [00:01<00:14, 21.0MBytes/s, 2024-03-29.csv]
# Tallying weapons used: 21921it [00:01, 12897.06it/s]00:14, 21.0MBytes/s, 2024-03-30.csv]
# Reading battles:  12%|█▏        | 37.3M/323M [00:01<00:13, 21.0MBytes/s, 2024-03-30.csv]
# Tallying weapons used: 31722it [00:02, 13955.25it/s]00:13, 21.0MBytes/s, 2024-03-31.csv]
# Reading battles:  15%|█▌        | 49.2M/323M [00:02<00:14, 19.2MBytes/s, 2024-03-31.csv]
# Tallying weapons used: 38574it [00:02, 13170.70it/s]00:14, 19.2MBytes/s, 2024-04-01.csv]
# Reading battles:  18%|█▊        | 59.3M/323M [00:02<00:13, 19.6MBytes/s, 2024-04-01.csv]
# Tallying weapons used: 45112it [00:03, 12993.62it/s]00:13, 19.6MBytes/s, 2024-04-02.csv]
# Reading battles:  22%|██▏       | 69.8M/323M [00:03<00:12, 20.1MBytes/s, 2024-04-02.csv]
# Tallying weapons used: 50357it [00:03, 12944.69it/s]00:12, 20.1MBytes/s, 2024-04-03.csv]
# Reading battles:  24%|██▍       | 78.2M/323M [00:03<00:12, 20.4MBytes/s, 2024-04-03.csv]
# Tallying weapons used: 55591it [00:04, 12983.10it/s]00:12, 20.4MBytes/s, 2024-04-04.csv]
# Reading battles:  27%|██▋       | 86.7M/323M [00:04<00:11, 20.6MBytes/s, 2024-04-04.csv]
# Tallying weapons used: 60853it [00:04, 12958.37it/s]00:11, 20.6MBytes/s, 2024-04-05.csv]
# Reading battles:  30%|██▉       | 96.0M/323M [00:04<00:10, 20.8MBytes/s, 2024-04-05.csv]
# Tallying weapons used: 67384it [00:05, 13002.87it/s]00:10, 20.8MBytes/s, 2024-04-06.csv]
# Reading battles:  33%|███▎      | 107M/323M [00:05<00:10, 20.9MBytes/s, 2024-04-06.csv]
# Tallying weapons used: 72574it [00:05, 12783.79it/s]0:10, 20.9MBytes/s, 2024-04-07.csv]
# Reading battles:  36%|███▌      | 116M/323M [00:05<00:09, 20.9MBytes/s, 2024-04-07.csv]
# Tallying weapons used: 77782it [00:05, 12889.08it/s]0:09, 20.9MBytes/s, 2024-04-08.csv]
# Reading battles:  38%|███▊      | 123M/323M [00:06<00:09, 20.9MBytes/s, 2024-04-08.csv]
# Tallying weapons used: 81684it [00:06, 12894.42it/s]0:09, 20.9MBytes/s, 2024-04-09.csv]
# Reading battles:  41%|████      | 131M/323M [00:06<00:09, 21.0MBytes/s, 2024-04-09.csv]
# Tallying weapons used: 86858it [00:06, 12838.51it/s]0:09, 21.0MBytes/s, 2024-04-10.csv]
# Reading battles:  43%|████▎     | 139M/323M [00:06<00:08, 21.0MBytes/s, 2024-04-10.csv]
# Tallying weapons used: 92034it [00:07, 12872.54it/s]0:08, 21.0MBytes/s, 2024-04-11.csv]
# Reading battles:  46%|████▌     | 147M/323M [00:07<00:08, 21.0MBytes/s, 2024-04-11.csv]
# Tallying weapons used: 98568it [00:07, 12973.27it/s]0:08, 21.0MBytes/s, 2024-04-12.csv]
# Reading battles:  49%|████▊     | 157M/323M [00:07<00:07, 21.0MBytes/s, 2024-04-12.csv]
# Tallying weapons used: 107942it [00:08, 13240.88it/s]:07, 21.0MBytes/s, 2024-04-13.csv]
# Reading battles:  53%|█████▎    | 172M/323M [00:08<00:07, 20.9MBytes/s, 2024-04-13.csv]
# Tallying weapons used: 114523it [00:08, 12997.20it/s]:07, 20.9MBytes/s, 2024-04-14.csv]
# Reading battles:  57%|█████▋    | 184M/323M [00:08<00:06, 21.0MBytes/s, 2024-04-14.csv]
# Tallying weapons used: 119735it [00:09, 12973.65it/s]:06, 21.0MBytes/s, 2024-04-15.csv]
# Reading battles:  60%|█████▉    | 193M/323M [00:09<00:06, 21.0MBytes/s, 2024-04-15.csv]
# Reading battles:  60%|█████▉    | 193M/323M [00:09<00:06, 20.3MBytes/s, 2024-04-16.csv]
# Tallying weapons used: 123260it [00:09, 12991.25it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 with weapon_only_model(mar_apr_battle_records) as mar_apr_model:
#       2     mar_apr_weapon_only_trace = pm.sample(1000, tune=1000, cores=4, progressbar=True, nuts_sampler="nutpie")
#
# Cell In[4], line 30, in weapon_only_model(battle_record_creator)
#       7 def weapon_only_model(
#       8     battle_record_creator: Callable[[], Iterable[BattleRecord]]
#       9 ) -> pm.Model:
#      10     """
#      11     Create a PyMC3 model for the given battle record creator.
#      12
#    (...)
#      28         A PyMC3 model for the given battle record creator.
#      29     """
# ---> 30     weapons = sorted(all_weapons_used(battle_record_creator()))
#      31     weapon_index = {weapon: i for i, weapon in enumerate(weapons)}
#      32     observed_weapon_variables, battle_results = (
#      33         all_observed_weapon_variables_and_battle_results(
#      34             battle_record_creator(), weapon_index
#      35         )
#      36     )
#
# File D:\Prj\Splatoon3Rank\battle_record_analysis.py:36, in all_weapons_used(battle_records)
#      23 """
#      24 Return the set of all weapons used in the given battle records.
#      25
#    (...)
#      30     The set of all weapons used in the given battle records.
#      31 """
#      32 participants: Iterable[BattleParticipant] = chain.from_iterable(
#      33     battle_record.participants.values()
#      34     for battle_record in tqdm(battle_records, desc="Tallying weapons used")
#      35 )
# ---> 36 return {participant.normalized_weapon for participant in participants}
#
# File D:\Prj\Splatoon3Rank\battle_record_analysis.py:36, in <setcomp>(.0)
#      23 """
#      24 Return the set of all weapons used in the given battle records.
#      25
#    (...)
#      30     The set of all weapons used in the given battle records.
#      31 """
#      32 participants: Iterable[BattleParticipant] = chain.from_iterable(
#      33     battle_record.participants.values()
#      34     for battle_record in tqdm(battle_records, desc="Tallying weapons used")
#      35 )
# ---> 36 return {participant.normalized_weapon for participant in participants}
#
# File D:\Prj\Splatoon3Rank\battle_record_analysis.py:32, in <genexpr>(.0)
#      22 def all_weapons_used(battle_records: Iterable[BattleRecord]) -> set[WeaponKey]:
#      23     """
#      24     Return the set of all weapons used in the given battle records.
#      25
#    (...)
#      30         The set of all weapons used in the given battle records.
#      31     """
# ---> 32     participants: Iterable[BattleParticipant] = chain.from_iterable(
#      33         battle_record.participants.values()
#      34         for battle_record in tqdm(battle_records, desc="Tallying weapons used")
#      35     )
#      36     return {participant.normalized_weapon for participant in participants}
#
# File D:\Programs\Miniforge3\envs\Splatoon3Rank\Lib\site-packages\tqdm\std.py:1181, in tqdm.__iter__(self)
#    1178 time = self._time
#    1180 try:
# -> 1181     for obj in iterable:
#    1182         yield obj
#    1183         # Update and possibly print the progressbar.
#    1184         # Note: does not call self.update(1) for speed optimisation.
#
# File D:\Prj\Splatoon3Rank\read_battle_records.py:344, in battle_records_from_zip(zip_file_path)
#     342 if filename.endswith(".csv"):
#     343     with z.open(filename) as file:
# --> 344         for battle in battles_from_csv(TextIOWrapper(file, "utf-8")):
#     345             yield battle
#     346     pbar.update(info.file_size)
#
# File D:\Prj\Splatoon3Rank\read_battle_records.py:312, in battles_from_csv(file)
#     308 reader = cast(DictReader, DictReader(file))
#     309 with_errs = (
#     310     battle_record_for_row(row_num, row) for row_num, row in enumerate(reader)
#     311 )
# --> 312 for value in with_errs:
#     313     if isinstance(value, Err):
#     314         value.log()
#
# File D:\Prj\Splatoon3Rank\read_battle_records.py:309, in <genexpr>(.0)
#     306 from csv import DictReader
#     308 reader = cast(DictReader, DictReader(file))
# --> 309 with_errs = (
#     310     battle_record_for_row(row_num, row) for row_num, row in enumerate(reader)
#     311 )
#     312 for value in with_errs:
#     313     if isinstance(value, Err):
#
# File D:\Programs\Miniforge3\envs\Splatoon3Rank\Lib\csv.py:111, in DictReader.__next__(self)
#     108 if self.line_num == 0:
#     109     # Used only for its side effect.
#     110     self.fieldnames
# --> 111 row = next(self.reader)
#     112 self.line_num = self.reader.line_num
#     114 # unlike the basic reader, we prefer not to return blanks,
#     115 # because we will typically wind up with a dict full of None
#     116 # values
#
# File D:\Programs\Miniforge3\envs\Splatoon3Rank\Lib\zipfile.py:1011, in ZipExtFile.read1(self, n)
#    1009 if n > 0:
#    1010     while not self._eof:
# -> 1011         data = self._read1(n)
#    1012         if n < len(data):
#    1013             self._readbuffer = data
#
# File D:\Programs\Miniforge3\envs\Splatoon3Rank\Lib\zipfile.py:1041, in ZipExtFile._read1(self, n)
#    1039 elif self._compress_type == ZIP_DEFLATED:
#    1040     n = max(n, self.MIN_READ_SIZE)
# -> 1041     data = self._decompressor.decompress(data, n)
#    1042     self._eof = (self._decompressor.eof or
#    1043                  self._compress_left <= 0 and
#    1044                  not self._decompressor.unconsumed_tail)
#    1045     if self._eof:
#
# KeyboardInterrupt:

# %%
import pickle

pickle.dump(
    mar_apr_kit_only_trace,
    open("2024-03-25-to-2024-04-26.kit_only_trace.pkl", "wb"),
)

# %%
az.summary(mar_apr_kit_only_trace)
# Out:
#                                mean     sd  hdi_3%  hdi_97%  mcse_mean  \
# weapon_strength[52gal]        0.088  0.003   0.082    0.093      0.000
# weapon_strength[52gal_deco]   0.105  0.004   0.097    0.112      0.000
# weapon_strength[96gal]        0.078  0.012   0.054    0.099      0.000
# weapon_strength[96gal_deco]   0.107  0.007   0.094    0.121      0.000
# weapon_strength[bamboo14mk1]  0.070  0.010   0.052    0.088      0.000
# ...                             ...    ...     ...      ...        ...
# weapon_strength_log__[115]   -2.719  0.076  -2.858   -2.581      0.001
# weapon_strength_log__[116]   -2.501  0.093  -2.671   -2.326      0.001
# weapon_strength_log__[117]   -2.445  0.040  -2.522   -2.374      0.001
# weapon_strength_log__[118]   -2.908  0.215  -3.306   -2.518      0.003
# weapon_strength_log__[119]   -2.840  0.164  -3.133   -2.530      0.002
#
#                               mcse_sd  ess_bulk  ess_tail  r_hat
# weapon_strength[52gal]          0.000    4435.0    2967.0    1.0
# weapon_strength[52gal_deco]     0.000    5529.0    2925.0    1.0
# weapon_strength[96gal]          0.000    5270.0    2559.0    1.0
# weapon_strength[96gal_deco]     0.000    5029.0    2716.0    1.0
# weapon_strength[bamboo14mk1]    0.000    4988.0    2676.0    1.0
# ...                               ...       ...       ...    ...
# weapon_strength_log__[115]      0.001    5708.0    3032.0    1.0
# weapon_strength_log__[116]      0.001    5021.0    2875.0    1.0
# weapon_strength_log__[117]      0.000    5551.0    2936.0    1.0
# weapon_strength_log__[118]      0.002    5182.0    2717.0    1.0
# weapon_strength_log__[119]      0.002    5085.0    2614.0    1.0
#
# [240 rows x 9 columns]

# %%
az.plot_trace(mar_apr_kit_only_trace)
# Out:
# array([[<Axes: title={'center': 'weapon_strength'}>,
#         <Axes: title={'center': 'weapon_strength'}>],
#        [<Axes: title={'center': 'weapon_strength_log__'}>,
#         <Axes: title={'center': 'weapon_strength_log__'}>]], dtype=object)

# %%
az.summary(mar_apr_kit_only_trace, var_names=["kit_strength"], fmt="long")
# Out:
#                    weapons  weapon_strength
# mean                 52gal            0.088
# mean            52gal_deco            0.105
# mean                 96gal            0.078
# mean            96gal_deco            0.107
# mean           bamboo14mk1            0.070
# ...                    ...              ...
# r_hat       variableroller            1.001
# r_hat  variableroller_foil            1.001
# r_hat               wakaba            1.000
# r_hat           wideroller            1.001
# r_hat   wideroller_collabo            1.002
#
# [1080 rows x 2 columns]
